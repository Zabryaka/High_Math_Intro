# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
a = 3
b = 0
k1 = 1
k2 = 6
x = np.linspace(-10, 10, 201)
y1 = k1 * np.cos(x - a) + b
y2 = k2 * np.cos(x - a) + b
plt.plot(x, y1, 'cyan')
plt.plot(x, y2, 'green')
plt.axis('equal')
# Out:
# (-11.0, 11.0, -6.598066164821801, 6.599907912610562)
